# %%
#@title Default title text
# Step 1 - install dependencies
# !pip install pandas # Preprocessing
# !pip install tweepy # Twitter API library
# !pip install twython
# !pip install vaderSentiment # Lexicon-based sentiment analysis
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.6/dist-packages (0.22.0)
# Requirement already satisfied: python-dateutil>=2 in /usr/local/lib/python3.6/dist-packages (from pandas) (2.5.3)
# Requirement already satisfied: pytz>=2011k in /usr/local/lib/python3.6/dist-packages (from pandas) (2018.9)
# Requirement already satisfied: numpy>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from pandas) (1.14.6)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil>=2->pandas) (1.11.0)
# Requirement already satisfied: tweepy in /usr/local/lib/python3.6/dist-packages (3.6.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tweepy) (1.11.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tweepy) (1.2.0)
# Requirement already satisfied: PySocks>=1.5.7 in /usr/local/lib/python3.6/dist-packages (from tweepy) (1.6.8)
# Requirement already satisfied: requests>=2.11.1 in /usr/local/lib/python3.6/dist-packages (from tweepy) (2.18.4)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from requests-oauthlib>=0.7.0->tweepy) (3.0.1)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.11.1->tweepy) (3.0.4)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.11.1->tweepy) (1.22)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.11.1->tweepy) (2018.11.29)
# Requirement already satisfied: idna<2.7,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.11.1->tweepy) (2.6)
# Requirement already satisfied: twython in /usr/local/lib/python3.6/dist-packages (3.7.0)
# Requirement already satisfied: requests>=2.1.0 in /usr/local/lib/python3.6/dist-packages (from twython) (2.18.4)
# Requirement already satisfied: requests-oauthlib>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from twython) (1.2.0)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.1.0->twython) (3.0.4)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.1.0->twython) (1.22)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.1.0->twython) (2018.11.29)
# Requirement already satisfied: idna<2.7,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.1.0->twython) (2.6)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from requests-oauthlib>=0.4.0->twython) (3.0.1)
# Requirement already satisfied: vaderSentiment in /usr/local/lib/python3.6/dist-packages (3.2.1)

# %%
# Step 2 - Import Dependencies
import tweepy
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import pandas as pd

# %%
# Step 3 - Configure Twitter API
consumer_key = 'pNJ0JvtCyS9euUasq62IKYK8j'
consumer_secret = 'dAc2nw4gOuvdrQGHKmVUMmjyA2YS7HpAvUJONIwuDcXTbBcGqr'
access_token = '33554253-WbpJzAjZtv2iBkLD4F2v1B7C0dssCKpFRS7DdsV7s'
access_token_secret = 'BOdAoNrvr65aU9b1V29VqlFLsJIe356RvKDoZgRV44G8d'

# %%
# Step 4 - Authenticate Twitter
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth)

# %%
# Step 5 - Define Cleaning Function

import re

def clean_tweet(tweet):
    '''
    Remove links and special characters
    '''
    return ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)", " ", tweet).split())

# %%
# Step 6 - Find Related Tweets
tweets = api.search('Donald Trump', count=200)

# Create a clean pandas dataframe as follows
data = pd.DataFrame(data=[clean_tweet(tweet.text) for tweet in tweets], columns=['Tweets'])

display(data.head(10))

print(tweets[0].id)
print(tweets[0].created_at)
print(tweets[0].source)
print(tweets[0].favorite_count)
print(tweets[0].retweet_count)
print(tweets[0].geo)
print(tweets[0].coordinates)
print(tweets[0].entities)

# %%
# Gather lexicon data
import nltk
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# True

# %%
# Step 7 - Go through the tweets to analyze their sentiment

sid = SentimentIntensityAnalyzer()

list = []
for index, row in data.iterrows():
  ss = sid.polarity_scores(row["Tweets"])
  list.append(ss)
se = pd.Series(list)
data['polarity'] = se.values

# We display the first 10 elements of dataframe
display(data.head(100))
# Out:
#                                                Tweets  \
# 0   RT YES YES YES Donald Trump Endorses Permanent...
# 1   RT Per usual Nancy Pelosi is playing 3D chess ...
# 2   RT EXCLUSIVE President Trump on Immigration I ...
# 3   RT BREAKING Fox News reporter had details of t...
# 4   RT If Democrats are calling for Donald Trump t...
# 5   RT Donald Trump takes off his hat at Mar a lag...
# 6   RT So it s a ok to abbreviate Tim Cook of Appl...
# 7   RT If Democrats are calling for Donald Trump t...
# 8   RT If Democrats are calling for Donald Trump t...
# 9   RT New ABC News confirms New Yorker account Fo...
# 10  RT So it s a ok to abbreviate Tim Cook of Appl...
# 11                      P I G FactsLivesMatter Resist
# 12  RT Donald Trump takes off his hat at Mar a lag...
# 13  RT If Democrats are calling for Donald Trump t...
# 14  RT Donald Trump Wants Facebook To Spy On Socia...
# 15  Bernie Sanders Calls Donald Trump A Pathologic...
# 16  Impeaching now means acquitting now When I hea...
# 17  Exclusive President Donald Trump on Immigratio...
# 18  RT Donald Trump takes off his hat at Mar a lag...
# 19  RT Trump Insists He Didn t Call Apple CEO Tim ...
# 20  She s got access to internal polling that show...
# 21  RT Nancy Pelosi is a person of few words and t...
# 22  RT Donald Trump takes off his hat at Mar a lag...
# 23  RT Rep Alexandria Ocasio Cortez suggests Repub...
# 24  RT New ABC News confirms New Yorker account Fo...
# 25  YOU HAVE ABOUT 300 CRIMINALS WANTED SORRY GENT...
# 26  RT Donald Trump Wants Facebook To Spy On Socia...
# 27  RT Trump s hamfisted economic policy has alrea...
# 28  Trump took the sign of white supremist who hat...
# 29  RT I would say Donald Trump is the equivalent ...
# ..                                                ...
# 70  RT New York State just dropped the subpoena ha...
# 71  RT New ABC News confirms New Yorker account Fo...
# 72  RT Donald Trump takes off his hat at Mar a lag...
# 73  RT NEW Maybe Congress should subpoena my clien...
# 74  RT Ugh I said you know what I ll sneak out pla...
# 75  RT House Speaker Nancy Pelosi D CA is ruling o...
# 76  RT Rep Ilhan Omar D MN said President Donald T...
# 77  This is funny that Republicans have not steppe...
# 78  RT The choice in 2020 will be clear FOR ABORTI...
# 79  RT Democrats want to change the voting age and...
# 80  RT NEW Maybe Congress should subpoena my clien...
# 81  RT Donald Trump s Approval Rating is at or nea...
# 82  RT You impeach Donald Trump We fucking get Mik...
# 83  RT The idea that Donald Trump is a reforming b...
# 84  RT Pundit It s not really true current black u...
# 85  RT Q How can you tell if Donald Trump is lying...
# 86  RT President Donald Trump on Immigration I Don...
# 87  RT New York State just dropped the subpoena ha...
# 88  RT A float in Sciacca Italy of Donald Trump Th...
# 89  RT Rep Ilhan Omar D MN said President Donald T...
# 90  RT Donald Trump is STILL onstage giving that s...
# 91       Jerome Powell Donald Trump can t fire me via
# 92  RT Donald Trump s lawyer called him a conman T...
# 93  RT Si el gobierno de Donald Trump contin a en ...
# 94  RT Don t lose the plot when it comes to Donald...
# 95  RT Donald Trump takes off his hat at Mar a lag...
# 96                              RT Trump is a prophet
# 97  New York State just dropped the subpoena hamme...
# 98  in case anyone is curious on how awful of a pe...
# 99  RT This man works until 2 AM and then sleeps o...
#
#                                              polarity
# 0   {'neg': 0.0, 'neu': 0.386, 'pos': 0.614, 'comp...
# 1   {'neg': 0.0, 'neu': 0.899, 'pos': 0.101, 'comp...
# 2   {'neg': 0.0, 'neu': 0.798, 'pos': 0.202, 'comp...
# 3   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 4   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 5   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 6   {'neg': 0.0, 'neu': 0.894, 'pos': 0.106, 'comp...
# 7   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 8   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 9   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 10  {'neg': 0.0, 'neu': 0.894, 'pos': 0.106, 'comp...
# 11  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 12  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 13  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 14  {'neg': 0.0, 'neu': 0.806, 'pos': 0.194, 'comp...
# 15  {'neg': 0.355, 'neu': 0.645, 'pos': 0.0, 'comp...
# 16  {'neg': 0.0, 'neu': 0.874, 'pos': 0.126, 'comp...
# 17  {'neg': 0.0, 'neu': 0.833, 'pos': 0.167, 'comp...
# 18  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 19  {'neg': 0.0, 'neu': 0.78, 'pos': 0.22, 'compou...
# 20  {'neg': 0.193, 'neu': 0.807, 'pos': 0.0, 'comp...
# 21  {'neg': 0.084, 'neu': 0.916, 'pos': 0.0, 'comp...
# 22  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 23  {'neg': 0.144, 'neu': 0.741, 'pos': 0.115, 'co...
# 24  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 25  {'neg': 0.156, 'neu': 0.662, 'pos': 0.182, 'co...
# 26  {'neg': 0.0, 'neu': 0.806, 'pos': 0.194, 'comp...
# 27  {'neg': 0.116, 'neu': 0.884, 'pos': 0.0, 'comp...
# 28  {'neg': 0.121, 'neu': 0.879, 'pos': 0.0, 'comp...
# 29  {'neg': 0.0, 'neu': 0.83, 'pos': 0.17, 'compou...
# ..                                                ...
# 70  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 71  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 72  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 73  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 74  {'neg': 0.107, 'neu': 0.69, 'pos': 0.203, 'com...
# 75  {'neg': 0.136, 'neu': 0.864, 'pos': 0.0, 'comp...
# 76  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 77  {'neg': 0.0, 'neu': 0.861, 'pos': 0.139, 'comp...
# 78  {'neg': 0.0, 'neu': 0.88, 'pos': 0.12, 'compou...
# 79  {'neg': 0.0, 'neu': 0.856, 'pos': 0.144, 'comp...
# 80  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 81  {'neg': 0.101, 'neu': 0.784, 'pos': 0.116, 'co...
# 82  {'neg': 0.081, 'neu': 0.766, 'pos': 0.153, 'co...
# 83  {'neg': 0.183, 'neu': 0.709, 'pos': 0.108, 'co...
# 84  {'neg': 0.214, 'neu': 0.786, 'pos': 0.0, 'comp...
# 85  {'neg': 0.185, 'neu': 0.815, 'pos': 0.0, 'comp...
# 86  {'neg': 0.0, 'neu': 0.936, 'pos': 0.064, 'comp...
# 87  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 88  {'neg': 0.0, 'neu': 0.795, 'pos': 0.205, 'comp...
# 89  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 90  {'neg': 0.0, 'neu': 0.806, 'pos': 0.194, 'comp...
# 91  {'neg': 0.255, 'neu': 0.745, 'pos': 0.0, 'comp...
# 92  {'neg': 0.158, 'neu': 0.842, 'pos': 0.0, 'comp...
# 93  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 94  {'neg': 0.197, 'neu': 0.803, 'pos': 0.0, 'comp...
# 95  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 96  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 97  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 98  {'neg': 0.204, 'neu': 0.706, 'pos': 0.09, 'com...
# 99  {'neg': 0.0, 'neu': 0.839, 'pos': 0.161, 'comp...
#
# [100 rows x 2 columns]
